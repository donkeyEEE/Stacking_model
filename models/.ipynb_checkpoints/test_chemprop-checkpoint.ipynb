# %%
import pandas as pd
from LAY2 import  ensemble_models
from DB.DB import db
from utils import Args

# %%
data_loader = db('../DataBase/DB2.csv')
# data_loader.get_data()
data_loader.data = data_loader.data.iloc[:10, :]
train, test = next(data_loader.get_folds())
# Out:
# data already finished size =13329
# fold0

# %%
#test.head()

# %%
args = Args(train, test, AFP=True, RF=True, MPNN=True,
            SVR=True, save_r=True, plot=True)

eb = ensemble_models()

# %%
# 训练第一层模型
recoder = eb.Lay1_models_train(args, save=True)
# Out:
# size of train is(8, 3) ,test is (2, 3)
# start training AFP
# 完成转换,start fitting
# train_mae 0.231987677176857
# test_mae 0.519445391830658
# test_R2 -0.656318861354102
# ============AFP over============
# start training MPNN
# 8it [00:00, ?it/s]
# 100%|██████████| 8/8 [00:00<?, ?it/s]
# 100%|██████████| 8/8 [00:00<00:00, 8006.31it/s]
# 2it [00:00, ?it/s]
# 100%|██████████| 2/2 [00:00<?, ?it/s]
# 100%|██████████| 2/2 [00:00<?, ?it/s]
# 2it [00:00, 2004.93it/s]
# 100%|██████████| 2/2 [00:00<?, ?it/s]
# 100%|██████████| 2/2 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#   8%|▊         | 2/25 [00:00<00:01, 15.15it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#  20%|██        | 5/25 [00:00<00:00, 20.69it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#  32%|███▏      | 8/25 [00:00<00:00, 24.33it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#  48%|████▊     | 12/25 [00:00<00:00, 27.35it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#  64%|██████▍   | 16/25 [00:00<00:00, 28.99it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#  80%|████████  | 20/25 [00:00<00:00, 29.87it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#  96%|█████████▌| 24/25 [00:00<00:00, 30.17it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:00<00:00, 27.89it/s]
# Loading training args
# Setting molecule featurization parameters to default.
# Loading data
# 2it [00:00, 2012.62it/s]
# 100%|██████████| 2/2 [00:00<?, ?it/s]
# Validating SMILES
# Test size = 2
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
# Loading pretrained parameter "ffn.7.weight".
# Loading pretrained parameter "ffn.7.bias".
# Moving model to cuda
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:07<00:00,  7.28s/it]
# 100%|██████████| 1/1 [00:08<00:00,  8.24s/it]
# Saving predictions to tmp/MPNN/test1.csv
# Elapsed time = 0:00:08
# Loading training args
# Setting molecule featurization parameters to default.
# Loading data
# 8it [00:00, ?it/s]
# 100%|██████████| 8/8 [00:00<?, ?it/s]
# Validating SMILES
# Test size = 8
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
# Loading pretrained parameter "ffn.7.weight".
# Loading pretrained parameter "ffn.7.bias".
# Moving model to cuda
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:07<00:00,  7.54s/it]
# 100%|██████████| 1/1 [00:08<00:00,  8.33s/it]
# Saving predictions to tmp/MPNN/train_MPNN.csv
# Elapsed time = 0:00:09
# ============MPNN over============
# start training RF
# train_mae 0.368870956625
# test_mae 0.4819493615
# test_R2 -0.07054278775189027
# ============RF over============
# start training SVR
# train_mae 0.10002832191569566
# test_mae 0.5016772673807458
# test_R2 -0.1023762425876269
# ============SVR over============

# %%
args.predict_df = test
# 第一层模型进行预测
eb.Lay1_models_predict(args)
# Out:
# AFP predict
# RF predict
# SVR predict
# MPNN predict
# Loading training args
# Setting molecule featurization parameters to default.
# Loading data
# 2it [00:00, ?it/s]
# 100%|██████████| 2/2 [00:00<?, ?it/s]
# Validating SMILES
# Test size = 2
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
# Loading pretrained parameter "ffn.7.weight".
# Loading pretrained parameter "ffn.7.bias".
# Moving model to cuda
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:07<00:00,  7.19s/it]
# 100%|██████████| 1/1 [00:08<00:00,  8.01s/it]
# Saving predictions to tmp/MPNN/predict_df2.csv
# Elapsed time = 0:00:08

# %%
eb.L1_predict_df
# Out:
#        true       AFP        RF       SVR      MPNN
# 0  1.611626  1.792105  2.221581  2.179444  2.257170
# 1  2.575525  1.717113  2.221581  2.139988  2.274799

# %%
args.model_lis_L2 = [True for i in range(3)]
args.plot = False
eb.Lay2_models_train(args,save=True)
# Out:
# start fitting L2 models
# Start fitting MLP
# Save MLR models
# Start fitting RF in L2
# Save MLR models
# start fitting SVR model
# Save SVR models

# %%
eb.Lay2_models_predict()

# %%
eb.L2_train_df
# Out:
#        true       MLP        RF       SVR
# 0  2.957682  2.985767  2.743808  2.857737
# 1  1.924011  1.913847  1.939652  2.024627
# 2  2.532971  2.519407  2.493107  2.432960
# 3  1.793378  1.864584  1.779609  1.811829
# 4  2.406205  2.351418  2.320126  2.305875
# 5  2.116431  2.205479  2.205010  2.215640
# 6  1.491494  1.465542  1.663552  1.591164
# 7  2.379425  2.295554  2.387350  2.286784
