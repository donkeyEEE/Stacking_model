# %%
import numpy as np
import pandas as pd

# %%
from models.Layers import ensemble_models
from DB.DB import db
from models.utils import Args
from models.utils import metric_r, metric_c
# Out:
# Skipped loading some Tensorflow models, missing a dependency. No module named 'tensorflow'
# Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'pytorch_lightning'
# Skipped loading some Jax models, missing a dependency. No module named 'jax'

# %%
# 加载数据集
data_loader = db('DataBase/DB.csv')
# data_loader.get_data()
data_loader.data = data_loader.data.iloc[:20, :]
# 五折切割
train, test = next(data_loader.get_folds())
# Out:
# data already finished size =9026
# fold0

# %%
train
# Out:
#        CASRN     LogLD                          smiles
# 0   100-00-5  2.719213     C1=CC(=CC=C1[N+](=O)[O-])Cl
# 1   100-02-7  2.285557      C1=CC(=CC=C1[N+](=O)[O-])O
# 2   100-14-1  3.257439    C1=CC(=CC=C1CCl)[N+](=O)[O-]
# 3   100-15-2  3.301030     CNC1=CC=C(C=C1)[N+](=O)[O-]
# 5   100-18-5  3.505150         CC(C)C1=CC=C(C=C1)C(C)C
# 6   100-20-9  3.397940     C1=CC(=CC=C1C(=O)Cl)C(=O)Cl
# 7   100-21-0  3.978089       C1=CC(=CC=C1C(=O)O)C(=O)O
# 8   100-28-7  3.204120  C1=CC(=CC=C1N=C=O)[N+](=O)[O-]
# 9   100-29-8  3.518514    CCOC1=CC=C(C=C1)[N+](=O)[O-]
# 11  100-36-7  3.451786                      CCN(CC)CCN
# 12  100-37-8  3.113943                      CCN(CC)CCO
# 14  100-42-5  3.459895                  C=CC1=CC=CC=C1
# 15  100-44-7  2.941449                C1=CC=C(C=C1)CCl
# 17  100-51-6  3.269513                 C1=CC=C(C=C1)CO
# 18  100-52-7  3.135133                C1=CC=C(C=C1)C=O
# 19  100-53-8  2.692847                 C1=CC=C(C=C1)CS

# %%
# 定义参数类
args = Args(train, test, AFP=True, RF=True, MPNN=True,
            SVR=True, save_r=False, plot=True,GAT=False, DNN=False,
            AD_FP=False)
# 实例化集成模型
eb = ensemble_models()

# %%
# 修改ECFP超参数
args.ECFP_Params=[4096,2]

# %%
# 训练第一层模型，save选择是否保存模
# 型
eb.Lay1_models_train(args ,save=True)
# Out:
# size of train is(16, 3) ,test is (4, 3)
# start training AFP
# 完成转换,start fitting
# test_rmse  is  0.7147845298955688
# test_mae  is  0.9781379172596549
# test_R2  is  -0.1566470777497837
# ============AFP over============
# start training MPNN
# 16it [00:00, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:00<?, ?it/s]
# 4it [00:00, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 3882.72it/s]
# 4it [00:00, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 3992.67it/s]
#   0%|                                                                                           | 0/25 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#   8%|██████▋                                                                            | 2/25 [00:00<00:01, 17.47it/s]
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#  24%|███████████████████▉                                                               | 6/25 [00:00<00:00, 26.98it/s]
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#  40%|████████████████████████████████▊                                                 | 10/25 [00:00<00:00, 30.63it/s]
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#  56%|█████████████████████████████████████████████▉                                    | 14/25 [00:00<00:00, 31.64it/s]
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#  72%|███████████████████████████████████████████████████████████                       | 18/25 [00:00<00:00, 32.81it/s]
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#  88%|████████████████████████████████████████████████████████████████████████▏         | 22/25 [00:00<00:00, 33.72it/s]
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 32.01it/s]
# Loading training args
# Setting molecule featurization parameters to default.
# Loading data
# 4it [00:00, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<?, ?it/s]
# Validating SMILES
# Test size = 4
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
# Loading pretrained parameter "ffn.7.weight".
# Loading pretrained parameter "ffn.7.bias".
# Moving model to cuda
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.88s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:08<00:00,  8.24s/it]
# Saving predictions to tmp/MPNN/test1.csv
# Elapsed time = 0:00:08
# Loading training args
# Setting molecule featurization parameters to default.
# Loading data
# 16it [00:00, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:00<?, ?it/s]
# Validating SMILES
# Test size = 16
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
# Loading pretrained parameter "ffn.7.weight".
# Loading pretrained parameter "ffn.7.bias".
# Moving model to cuda
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.81s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:08<00:00,  8.14s/it]
# Saving predictions to tmp/MPNN/train_MPNN.csv
# Elapsed time = 0:00:08
# ============MPNN over============
# start training RF
# test_rmse  is  0.7527640135
# test_mae  is  1.0377200812371739
# test_R2  is  -0.30185051077184233
# ============RF over============
# start training SVR
# test_rmse  is  0.777392168043055
# test_mae  is  1.077552195232148
# test_R2  is  -0.4037097221526904
# ============SVR over============

# %%
# 设置第二层模型参数 args.model_lis_L2
args.model_lis_L2 = [True for i in range(3)]
args.plot = True
eb.Lay2_models_train(args,save=True)
# Out:
# start fitting L2 models
# Start fitting MLP
# Save MLR models
# Start fitting RF in L2
# Save RF models
# start fitting SVR model
# Save SVR models
